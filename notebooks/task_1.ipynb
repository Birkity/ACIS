# %%
import csv
import pandas as pd
from pathlib import Path

# %%
input_path = Path("../Data/MachineLearningRating_v3.txt")
output_path = Path("data.csv")


df = pd.read_csv(input_path, sep='|')


df.to_csv(output_path, index=False)


df.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_21252\201787109.py:5: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_path, sep='|')
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %% [markdown]
# Data Understanding

# %%
print(df.head())

print(df.info())

print(df.dtypes)
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
print(df.describe())
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %% [markdown]
# Descriptive Statistics

# %%
total_premium_stats = df['TotalPremium'].describe()
total_claims_stats = df['TotalClaims'].describe()
print(total_premium_stats)
print(total_claims_stats)
# Out:
# count    1.000098e+06
# mean     6.190550e+01
# std      2.302845e+02
# min     -7.825768e+02
# 25%      0.000000e+00
# 50%      2.178333e+00
# 75%      2.192982e+01
# max      6.528260e+04
# Name: TotalPremium, dtype: float64
# count    1.000098e+06
# mean     6.486119e+01
# std      2.384075e+03
# min     -1.200241e+04
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.930921e+05
# Name: TotalClaims, dtype: float64

# %% [markdown]
# Data Quality Assessment

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['TotalPremium'].hist(bins=50)
plt.title('Total Premium Distribution')
plt.show()

df['TotalClaims'].hist(bins=50)
plt.title('Total Claims Distribution')
plt.show()

df['Gender'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.show()

# %%
corr_matrix = df[['TotalPremium', 'TotalClaims']].corr()
print(corr_matrix)

sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation between Total Premium and Total Claims')
plt.show()
# Out:
#               TotalPremium  TotalClaims
# TotalPremium      1.000000     0.121588
# TotalClaims       0.121588     1.000000

# %%
df.plot.scatter(x='TotalPremium', y='TotalClaims')
plt.title('Total Premium vs. Total Claims')
plt.show()

# %%
sns.boxplot(x=df['TotalPremium'])
plt.title('Boxplot for Total Premium')
plt.show()

sns.boxplot(x=df['TotalClaims'])
plt.title('Boxplot for Total Claims')
plt.show()

# %%
df.groupby('Province')['TotalPremium'].mean().plot(kind='bar')
plt.title('Average Premium per Province')
plt.show()

df.groupby('PostalCode')['TotalPremium'].mean().plot(kind='line')
plt.title('Average Premium by PostalCode')
plt.show()

# %%
sns.boxplot(data=df, x='VehicleType', y='TotalClaims')
plt.title('Total Claims by Vehicle Type')
plt.show()

# %%
import numpy as np
df_cleaned = df.drop(columns=['CrossBorder', 'NumberOfVehiclesInFleet'])

df_cleaned['CustomValueEstimate'] = df_cleaned['CustomValueEstimate'].fillna(df_cleaned['CustomValueEstimate'].median())


df_cleaned['Bank'] = df_cleaned['Bank'].fillna(df_cleaned['Bank'].mode()[0])
df_cleaned['AccountType'] = df_cleaned['AccountType'].fillna(df_cleaned['AccountType'].mode()[0])
df_cleaned['Gender'] = df_cleaned['Gender'].fillna(df_cleaned['Gender'].mode()[0])
df_cleaned['MaritalStatus'] = df_cleaned['MaritalStatus'].fillna(df_cleaned['MaritalStatus'].mode()[0])
df_cleaned['NewVehicle'] = df_cleaned['NewVehicle'].fillna(df_cleaned['NewVehicle'].mode()[0])


df_cleaned.dropna(inplace=True)


def cap_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return np.clip(series, lower_bound, upper_bound)

df_cleaned['TotalPremium'] = cap_outliers(df_cleaned['TotalPremium'])
df_cleaned['TotalClaims'] = cap_outliers(df_cleaned['TotalClaims'])

df_cleaned.to_csv('data_cleaned.csv', index=False)
df_cleaned.head()
# Out:
#     UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 12               127439     10874  2015-02-01 00:00:00             True
# 13               127445     10874  2014-12-01 00:00:00             True
# 14               127445     10874  2015-03-01 00:00:00             True
# 15               127445     10874  2015-05-01 00:00:00             True
# 16               127445     10874  2015-07-01 00:00:00             True
#
#    Citizenship          LegalType Title Language                 Bank  \
# 12              Close Corporation    Mr  English  First National Bank
# 13              Close Corporation    Mr  English  First National Bank
# 14              Close Corporation    Mr  English  First National Bank
# 15              Close Corporation    Mr  English  First National Bank
# 16              Close Corporation    Mr  English  First National Bank
#
#         AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
numerical_cols = ['TotalPremium', 'TotalClaims', 'SumInsured', 'CalculatedPremiumPerTerm', 'CustomValueEstimate']
descriptive_stats = df_cleaned[numerical_cols].describe()
print(descriptive_stats)

for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df_cleaned[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
#         TotalPremium  TotalClaims    SumInsured  CalculatedPremiumPerTerm  \
# count  358195.000000     358195.0  3.581950e+05             358195.000000
# mean       15.994630          0.0  6.196967e+05                123.832465
# std        22.333314          0.0  1.523034e+06                231.912210
# min       -32.894737          0.0  1.000000e-02                  0.000000
# 25%         0.000000          0.0  5.000000e+03                  3.429000
# 50%         2.728509          0.0  7.500000e+03                  8.674200
# 75%        21.929825          0.0  2.660000e+05                 98.576300
# max        54.824561          0.0  5.000000e+06               1754.411800
#
#        CustomValueEstimate
# count        358195.000000
# mean         217243.072560
# std           61888.598004
# min           23100.000000
# 25%          220000.000000
# 50%          220000.000000
# 75%          220000.000000
# max          715712.000000

# %%
corr_matrix_full = df_cleaned[numerical_cols].corr()


plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix_full, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='TotalPremium', y='TotalClaims', hue='VehicleType', data=df_cleaned)
plt.title('Total Premium vs Total Claims by Vehicle Type')
plt.show()

plt.figure(figsize=(8, 6))
sns.countplot(x='CoverType', data=df_cleaned)
plt.title('Distribution of Insurance Cover Types')
plt.xticks(rotation=45)
plt.show()

sns.pairplot(df_cleaned[numerical_cols])
plt.show()
